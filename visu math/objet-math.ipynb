# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
name = input("quel est le nom de t'as forme")

# Paramètres de la bouteille de Klein 
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 50)
u, v = np.meshgrid(u, v)

# Formules paramétriques pour la bouteille de Klein
x = (2 + np.cos(u / 2) * np.sin(v) - np.sin(u / 2) * np.sin(2 * v)) * np.cos(u)
y = (2 + np.cos(u / 2) * np.sin(v) - np.sin(u / 2) * np.sin(2 * v)) * np.sin(u)
z = np.sin(u / 2) * np.sin(v) + np.cos(u / 2) * np.sin(2 * v)

# %%
fig = go.Figure(data=[go.Surface(z=z, x=x, y=y, colorscale="Viridis")])

fig.update_layout(title=f"{name}")
fig.show()
